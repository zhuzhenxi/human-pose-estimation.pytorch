# %% [markdown]
# <a href="https://colab.research.google.com/github/zhuzhenxi/human-pose-estimation.pytorch/blob/master/test_12_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 1.3.1

# %%
# !git clone https://github.com/microsoft/human-pose-estimation.pytorch.git
# Out:
# Cloning into 'human-pose-estimation.pytorch'...
# remote: Enumerating objects: 188, done.
# remote: Total 188 (delta 0), reused 0 (delta 0), pack-reused 188
# Receiving objects: 100% (188/188), 68.79 KiB | 582.00 KiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
# %cd /content/human-pose-estimation.pytorch/models/pytorch/imagenet
# Out:
# /content/human-pose-estimation.pytorch/models/pytorch/imagenet

# %%
state_dict = torch.hub.load_state_dict_from_url('https://s3.amazonaws.com/pytorch/models/resnet152-b121ed2d.pth','/content/human-pose-estimation.pytorch/models/pytorch/imagenet')
# Out:
# Downloading: "https://s3.amazonaws.com/pytorch/models/resnet152-b121ed2d.pth" to /content/human-pose-estimation.pytorch/models/pytorch/imagenet/resnet152-b121ed2d.pth
# 100%|██████████| 230M/230M [00:06<00:00, 36.6MB/s]

# %%
# !wget https://drive.google.com/open?id=1cQqWIu32FLQdtcPeLhyJx2arVNkqa1Mp
# Out:
# --2019-12-22 05:29:45--  https://drive.google.com/open?id=1cQqWIu32FLQdtcPeLhyJx2arVNkqa1Mp
# Resolving drive.google.com (drive.google.com)... 74.125.142.102, 74.125.142.100, 74.125.142.139, ...
# Connecting to drive.google.com (drive.google.com)|74.125.142.102|:443... connected.
# HTTP request sent, awaiting response... 307 OK
# Location: https://drive.google.com/file/d/1cQqWIu32FLQdtcPeLhyJx2arVNkqa1Mp/view?usp=drive_open [following]
# --2019-12-22 05:29:46--  https://drive.google.com/file/d/1cQqWIu32FLQdtcPeLhyJx2arVNkqa1Mp/view?usp=drive_open
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘open?id=1cQqWIu32FLQdtcPeLhyJx2arVNkqa1Mp’
#
# open?id=1cQqWIu32FL     [ <=>                ]  67.08K  --.-KB/s    in 0.02s
#
# 2019-12-22 05:29:46 (4.36 MB/s) - ‘open?id=1cQqWIu32FLQdtcPeLhyJx2arVNkqa1Mp’ saved [68688]

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !python pose_estimation/train.py \
    --cfg experiments/mpii/resnet50/256x256_d256x3_adam_lr1e-3.yaml
# Out:
# => creating output/mpii/pose_resnet_50/256x256_d256x3_adam_lr1e-3
# => creating log/mpii/pose_resnet_50/256x256_d256x3_adam_lr1e-3_2019-12-22-07-44
# Namespace(cfg='experiments/mpii/resnet50/256x256_d256x3_adam_lr1e-3.yaml', frequent=100, gpus=None, workers=None)
# {'CUDNN': {'BENCHMARK': True, 'DETERMINISTIC': False, 'ENABLED': True},
#  'DATASET': {'DATASET': 'mpii',
#              'DATA_FORMAT': 'jpg',
#              'FLIP': True,
#              'HYBRID_JOINTS_TYPE': '',
#              'ROOT': 'data/mpii/',
#              'ROT_FACTOR': 30,
#              'SCALE_FACTOR': 0.25,
#              'SELECT_DATA': False,
#              'TEST_SET': 'valid',
#              'TRAIN_SET': 'train'},
#  'DATA_DIR': '',
#  'DEBUG': {'DEBUG': False,
#            'SAVE_BATCH_IMAGES_GT': True,
#            'SAVE_BATCH_IMAGES_PRED': True,
#            'SAVE_HEATMAPS_GT': True,
#            'SAVE_HEATMAPS_PRED': True},
#  'GPUS': '0',
#  'LOG_DIR': 'log',
#  'LOSS': {'USE_TARGET_WEIGHT': True},
# ...

# %%
# !python pose_estimation/valid.py \
    --cfg experiments/mpii/resnet50/256x256_d256x3_adam_lr1e-3.yaml \
    --flip-test \
    --model-file models/pytorch/pose_mpii/pose_resnet_50_256x256.pth.tar
# Out:
# => creating output/mpii/pose_resnet_50/256x256_d256x3_adam_lr1e-3
# => creating log/mpii/pose_resnet_50/256x256_d256x3_adam_lr1e-3_2019-12-22-07-40
# Namespace(cfg='experiments/mpii/resnet50/256x256_d256x3_adam_lr1e-3.yaml', coco_bbox_file=None, flip_test=True, frequent=100, gpus=None, model_file='models/pytorch/pose_mpii/pose_resnet_50_256x256.pth.tar', post_process=False, shift_heatmap=False, use_detect_bbox=False, workers=None)
# {'CUDNN': {'BENCHMARK': True, 'DETERMINISTIC': False, 'ENABLED': True},
#  'DATASET': {'DATASET': 'mpii',
#              'DATA_FORMAT': 'jpg',
#              'FLIP': True,
#              'HYBRID_JOINTS_TYPE': '',
#              'ROOT': 'data/mpii/',
#              'ROT_FACTOR': 30,
#              'SCALE_FACTOR': 0.25,
#              'SELECT_DATA': False,
#              'TEST_SET': 'valid',
#              'TRAIN_SET': 'train'},
#  'DATA_DIR': '',
#  'DEBUG': {'DEBUG': False,
#            'SAVE_BATCH_IMAGES_GT': True,
# ...
